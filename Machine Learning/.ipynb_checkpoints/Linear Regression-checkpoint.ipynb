# %%
# Anita Sehn Brose

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('heart.csv') #import the dataframe

# %%
df.corr() #view the dataframe
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
# Created a graphic that shows the correlation between the rows

cmap =sns.diverging_palette(5, 250, as_cmap=True)

def magnify():                        # defined the style of the graphic 
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
df.corr().style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# C:\Users\AnitaSehnBrose\AppData\Local\Temp\ipykernel_21872\4001788751.py:16: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient(cmap, axis=1)\
# <style type="text/css">
# #T_57ee8 th {
#   font-size: 7pt;
# }
# #T_57ee8 td {
#   padding: 0em 0em;
# }
# #T_57ee8 th:hover {
#   font-size: 12pt;
# }
# #T_57ee8 tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_57ee8_row0_col0, #T_57ee8_row1_col1, #T_57ee8_row2_col2, #T_57ee8_row3_col3, #T_57ee8_row4_col4, #T_57ee8_row5_col5, #T_57ee8_row6_col6, #T_57ee8_row7_col7, #T_57ee8_row8_col8, #T_57ee8_row9_col9, #T_57ee8_row10_col10, #T_57ee8_row11_col11, #T_57ee8_row12_col12, #T_57ee8_row13_col13 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col1, #T_57ee8_row5_col0, #T_57ee8_row6_col10 {
#   background-color: #e28698;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col2, #T_57ee8_row2_col4, #T_57ee8_row4_col11 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col3, #T_57ee8_row0_col11, #T_57ee8_row11_col0 {
#   background-color: #f1e8ea;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col4 {
#   background-color: #efdcdf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col5 {
#   background-color: #ebc2ca;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col6, #T_57ee8_row1_col2 {
#   background-color: #e17e92;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col7, #T_57ee8_row1_col13, #T_57ee8_row2_col8, #T_57ee8_row3_col13, #T_57ee8_row4_col1, #T_57ee8_row5_col6, #T_57ee8_row6_col4, #T_57ee8_row7_col0, #T_57ee8_row8_col13, #T_57ee8_row9_col10, #T_57ee8_row10_col9, #T_57ee8_row11_col13, #T_57ee8_row12_col13, #T_57ee8_row13_col8, #T_57ee8_row13_col9 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col8, #T_57ee8_row8_col3 {
#   background-color: #eab9c3;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col9 {
#   background-color: #efd9dd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col10, #T_57ee8_row1_col3 {
#   background-color: #e0748a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col12, #T_57ee8_row9_col6 {
#   background-color: #e9b5bf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row0_col13 {
#   background-color: #dd657d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col0, #T_57ee8_row5_col8 {
#   background-color: #df6d84;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col4 {
#   background-color: #db526e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col5 {
#   background-color: #e492a3;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col6, #T_57ee8_row3_col8, #T_57ee8_row3_col12 {
#   background-color: #e17a8f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col7, #T_57ee8_row12_col10 {
#   background-color: #e17d91;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col8, #T_57ee8_row10_col5, #T_57ee8_row12_col4 {
#   background-color: #e9b2bd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col9, #T_57ee8_row3_col5 {
#   background-color: #e7a3b0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col10, #T_57ee8_row10_col8 {
#   background-color: #e28396;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col11, #T_57ee8_row10_col12, #T_57ee8_row12_col0 {
#   background-color: #e8abb7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row1_col12, #T_57ee8_row9_col5 {
#   background-color: #ecc3cb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col0, #T_57ee8_row12_col6, #T_57ee8_row13_col4 {
#   background-color: #e491a1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col1, #T_57ee8_row9_col2, #T_57ee8_row10_col0 {
#   background-color: #e599a8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col3, #T_57ee8_row7_col6 {
#   background-color: #e8aeba;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col5 {
#   background-color: #eab8c2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col6, #T_57ee8_row10_col11 {
#   background-color: #e9afbb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col7, #T_57ee8_row9_col11 {
#   background-color: #eff0f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col9, #T_57ee8_row2_col11 {
#   background-color: #e0768b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col10, #T_57ee8_row8_col11 {
#   background-color: #ecc6ce;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col12, #T_57ee8_row6_col7 {
#   background-color: #e0798d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row2_col13 {
#   background-color: #d0dae8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col0 {
#   background-color: #ebbfc8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col1 {
#   background-color: #da4e6a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col2, #T_57ee8_row4_col10 {
#   background-color: #e07389;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col4 {
#   background-color: #e48fa0;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col6, #T_57ee8_row6_col0 {
#   background-color: #d8405e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col7, #T_57ee8_row5_col7, #T_57ee8_row9_col13 {
#   background-color: #dc5b75;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col9, #T_57ee8_row10_col3 {
#   background-color: #e7a4b1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col10 {
#   background-color: #d8415f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row3_col11 {
#   background-color: #e3889a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col0, #T_57ee8_row8_col4, #T_57ee8_row10_col1 {
#   background-color: #eabbc4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col2 {
#   background-color: #dc5e77;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col3 {
#   background-color: #e69ead;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col5 {
#   background-color: #e18093;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col6, #T_57ee8_row8_col7, #T_57ee8_row13_col11 {
#   background-color: #d94a67;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col7, #T_57ee8_row13_col0 {
#   background-color: #df7086;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col8, #T_57ee8_row4_col9, #T_57ee8_row11_col6, #T_57ee8_row12_col5 {
#   background-color: #e38b9d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col12 {
#   background-color: #e595a5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row4_col13, #T_57ee8_row6_col1 {
#   background-color: #db5872;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col1, #T_57ee8_row5_col4, #T_57ee8_row8_col10 {
#   background-color: #de667e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col2, #T_57ee8_row6_col2 {
#   background-color: #e0778c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col3, #T_57ee8_row8_col6 {
#   background-color: #e59aa9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col9 {
#   background-color: #dd6179;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col10, #T_57ee8_row6_col5 {
#   background-color: #d94865;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col11 {
#   background-color: #e38a9c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_57ee8_row5_col12, #T_57ee8_row5

# %%
# split the dataset in train and test 
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1],
                                                    df.iloc[:, -1],
                                                    test_size=0.2)

# %%
# Normalizing variables with the support of Logistic Regression Model Tuning with scikit-learn — Part 1

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
logistic_regression = LogisticRegression()
preds = logistic_regression.fit(X_train, y_train).predict(X_test)

# %%
# Saw the shape of the variables
print(y_train.shape, X_train.shape, X_test.shape, y_test.shape, preds.shape)
# Out:
# (820,) (820, 13) (205, 13) (205,) (205,)

# %%
#  Calculating the accuracy of the model
logistic_acc = accuracy_score(y_test, preds)
print('Logistic Accuracy: {}'.format(logistic_acc))
# Out:
# Logistic Accuracy: 0.8341463414634146

# %%
# Calculated the confusion matrix

conf_matrix = confusion_matrix(y_test, pred.round(0).astype(int))

# Printed the confusion matrix using Matplotlib

fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Logistic Regression - General', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21872\3281952291.py in <module>
#       1 # Calculated the confusion matrix
#       2
# ----> 3 conf_matrix = confusion_matrix(y_test, pred.round(0).astype(int))
#       4
#       5 # Printed the confusion matrix using Matplotlib
#
# NameError: name 'pred' is not defined

# %%
# Calculated the classification report
print(classification_report(y_test, pred))

# %%
#  Filtred the dataframe, leaving only the data which can be taken from wearables
wearable_df = df[['age', 'sex', 'trestbps', 'fbs', 'restecg', 'thalach',
                 'oldpeak', 'slope', 'target']]

# %%
df.head()

# %%
# split the dataset in train and test again
X_train, X_test, y_train, y_test = train_test_split(wearable_df.iloc[:, :-1],
                                                    wearable_df.iloc[:, -1],
                                                    test_size=0.3)

# printed the shape of the variables
print(y_train.shape, X_train.shape, X_test.shape, y_test.shape)

# %%
# Normalizing variables with the support of Logistic Regression Model Tuning with scikit-learn — Part 1

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression()
pred2 = logistic_regression.fit(X_train, y_train).predict(X_test)

# %%
# Calculated the accuracy of the model
logistic_acc = accuracy_score(y_test, pred2)
print('Logistic Accuracy: {}'.format(logistic_acc))

# %%
#  The acuracy of the model was reducted when the dataset was filtered, but that was expected.

# %%
# Calculated the precision of the model
from sklearn.metrics import precision_score
logistic_precision = precision_score(y_test, 
                                     pred2)
print('Logistic Precision: {}'.format(logistic_precision))

# %%
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_test,pred2.round(0).astype(int))
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Logistic Regression - Filtered', fontsize=18)
plt.show()

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test, pred2))
